# %% [markdown]
# ## 聖杯方法

# %%
import pandas
df = pandas.read_csv('data/holy_grail_result.csv', index_col = 0)
df.head()
# Out:
#                equal  holy_grail
# Date
# 2021-01-04  1.000000         1.0
# 2021-01-05  1.000803         1.0
# 2021-01-06  0.988709         1.0
# 2021-01-07  0.995705         1.0
# 2021-01-08  1.003351         1.0

# %%
df.plot(kind = 'line', figsize = [20,10])
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## 購買股票
# - 2498,9945
